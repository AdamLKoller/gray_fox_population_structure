# %% [markdown]
# ### Importing modules

# %%
import pandas as pd

# %%
allele_stats_2 = pd.read_table('../tables/allele_stats_2.tab')
allele_stats_2.index = ['NW','SW & E']
allele_stats_2.round(3)
# Out:
#         Allelic_Richness  Observed_Heterozygosity  Expected_Heterozygosity  \
# NW                 1.696                    0.159                    0.165
# SW & E             1.874                    0.173                    0.183
#
#               N    Fis  Private_Alleles
# NW       50.808  0.033               11
# SW & E  180.036  0.053              446

# %%
allele_stats_3 = pd.read_table('../tables/allele_stats_3.tab')
allele_stats_3.index = ['NW','E','SW']
allele_stats_3.round(3)
# Out:
#     Allelic_Richness  Observed_Heterozygosity  Expected_Heterozygosity  \
# NW             1.660                    0.158                    0.163
# E              1.831                    0.175                    0.184
# SW             1.776                    0.170                    0.177
#
#           N    Fis  Private_Alleles
# NW   45.836  0.030               10
# E   107.176  0.043              127
# SW   77.831  0.036               38

# %%
allele_stats_ap = pd.read_table('../tables/allele_stats_apriori.tab')
allele_stats_ap.index = allele_stats_ap['Population']
allele_stats_ap.round(3)[['N','Allelic_Richness','Observed_Heterozygosity',
                         'Expected_Heterozygosity','Fis','Private_Alleles']]
# Out:
#                  N  Allelic_Richness  Observed_Heterozygosity  \
# Population
# AR          26.941             1.175                    0.168
# IA_NE       10.647             1.166                    0.161
# IL_IN       12.422             1.177                    0.172
# KS_OK       11.496             1.180                    0.173
# KY_TN       55.323             1.184                    0.176
# LA           5.601             1.184                    0.178
# MI           4.547             1.174                    0.173
# MN_WI_ND    24.950             1.157                    0.154
# MO          45.750             1.174                    0.169
# MS          14.507             1.181                    0.178
# OH_WV       10.294             1.173                    0.168
# SC_NC        8.366             1.173                    0.177
#
#             Expected_Heterozygosity    Fis  Private_Alleles
# Population
# AR                            0.175  0.031                0
# ...
