# %%
# %%R
# install.packages('pcadapt')
# Out:
# R[write to console]: Installing package into ‘/home/LC/kollad01/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependencies ‘doParallel’, ‘bigparallelr’, ‘nabor’, ‘robustbase’, ‘ff’, ‘bigutilsr’, ‘mmapcharr’, ‘RSpectra’, ‘rmio’
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/doParallel_1.0.17.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 164254 bytes (160 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %% [markdown]
# ### Loading R magic

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# ### Loading libraries

# %%
# %%R
# library(pcadapt)
# Out:
# R[write to console]: Error in library(pcadapt) : there is no package called ‘pcadapt’
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  library ‘/usr/lib/R/site-library’ contains no packages
# Error in library(pcadapt) : there is no package called ‘pcadapt’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:283, in RMagics.eval(self, code)
#     281 try:
#     282     # Need the newline in case the last line in code is a comment.
# --> 283     value, visible = ro.r("withVisible({%s\n})" % code)
#     284 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     285     # Otherwise next return seems to have copy of error.
#
# ...
